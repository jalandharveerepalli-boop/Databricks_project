# %%
from pyspark.sql.functions import *

# %%
df = spark.read.table("databricks_av_cata.bronze.regions")
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@datalakete.dfs.core.windows.net/regions")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_av_cata.silver.regions
USING DELTA
LOCATION "abfss://silver@datalakete.dfs.core.windows.net/regions"

# %%
# %sql
select * from databricks_av_cata.silver.regions
